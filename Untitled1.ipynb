# %%
import torch
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from sklearn.preprocessing import normalize

# %%
import numpy as np

# %%
a = np.sin(np.linspace(-np.pi,np.pi,100))

# %%
b = (a - np.min(a)) / np.max(a)

# %%
plt.plot(b)
